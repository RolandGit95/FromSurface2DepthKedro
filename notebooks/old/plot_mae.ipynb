# %%
import numpy as np
import matplotlib.pyplot as plt 
import os, sys, glob, re

# %%
folder = '../data/05_validation/regimeB'
#prefix = 'STLSTM_t_1_6_12_17_22_27_32_d_'
#prefix = 'STLSTM_t_1_6_12_18_24_32_v2_d_'
#prefix = 'STLSTM_t_1_6_12_18_24_32_v2_d_'
prefix = 'STLSTM_t_1_6_12_18_24_32_v2_d_'
prefix = 'STLSTM_t_0_2_4_6_8_10_12_14_16_18_20_22_24_26_28_30_31_d_'
full = os.path.join(folder, prefix + '*')

def atoi(text):
    return int(text) if text.isdigit() else text

def natural_keys(text):
    return [atoi(c) for c in re.split(r'(\d+)', text)]

files = glob.glob(full)
files.sort(key=natural_keys)

losses = []
for i, file in enumerate(files):
    l = np.load(file)
    losses.append(l)
    
plt.plot(losses)

# %%
folder = '../data/05_validation/regimeB'
#prefix = 'STLSTM_t_1_6_12_17_22_27_32_d_'
#prefix = 'STLSTM_t_1_6_12_18_24_32_v2_d_'
prefix = 'STLSTM_t_1_6_12_18_24_32_v2_d_'
prefix = 'STLSTM_t_1_6_12_18_24_32_v2_d_'
#prefix = 'STLSTM_t_0_2_4_6_8_10_12_14_16_18_20_22_24_26_28_30_31_d_'
full = os.path.join(folder, prefix + '*')

def atoi(text):
    return int(text) if text.isdigit() else text

def natural_keys(text):
    return [ atoi(c) for c in re.split(r'(\d+)', text) ]

files = glob.glob(full)
files.sort(key=natural_keys)

losses = []
for i, file in enumerate(files):
    l = np.load(file)
    losses.append(l)
    
plt.plot(losses)

# %%
losses = []
for i, file in enumerate(files):
    l = np.load(file)
    losses.append(l)

# %%
X = np.load('/home/roland/Projekte/Tests/FromSurface2DepthKedro/data/02_primary/regimeB/X_test/X_test_00.npy')
Y = np.load('/home/roland/Projekte/Tests/FromSurface2DepthKedro/data/02_primary/regimeB/Y_test/Y_test_00.npy')

# %%
x.shape, y.shape
x
# Out:
# array([[[[[-127, -127, -127, ..., -126, -125, -125],
#           [-127, -127, -127, ..., -126, -125, -125],
#           [-127, -127, -127, ..., -126, -125, -125],
#           ...,
#           [-127, -127, -127, ...,  120,  121,  121],
#           [-127, -127, -127, ...,  122,  122,  122],
#           [-127, -127, -127, ...,  122,  122,  122]]],
#
#
#         [[[-127, -127, -127, ..., -127, -127, -127],
#           [-127, -127, -127, ..., -127, -127, -127],
#           [-127, -127, -127, ..., -127, -127, -127],
#           ...,
#           [-126, -126, -126, ...,  113,  114,  114],
#           [-126, -126, -126, ...,  116,  116,  117],
#           [-126, -126, -126, ...,  116,  117,  117]]],
#
#
#         [[[-127, -127, -127, ..., -127, -127, -127],
#           [-127, -127, -127, ..., -127, -127, -127],
#           [-127, -127, -127, ..., -127, -127, -127],
#           ...,
#           [-124, -124, -124, ...,   98,   99,  100],
#           [-124, -124, -124, ...,  103,  104,  105],
# ...

# %%
plt.imshow(y[0,0,0])

# %%
x = np.load('/home/roland/Projekte/Tests/FromSurface2DepthKedro/data/04_model_output/regimeB/STLSTM_t_0_2_4_6_8_10_12_14_16_18_20_22_24_26_28_30_31_d_10_X_test_00.npy')

# %%
x.shape
# Out:
# (3072, 1, 1, 120, 120)

# %%
plt.imshow(x[0,0,0])

# %%
Y[0,0,10] - x[0,0,0]
# Out:
# array([[ -97.03062 ,  -96.01317 ,  -89.00922 , ...,   66.96409 ,
#           78.9499  ,   80.91698 ],
#        [ -96.0071  ,  -95.004074,  -88.00357 , ...,   63.97025 ,
#           76.97432 ,   78.94656 ],
#        [ -96.00507 ,  -95.003365,  -88.00399 , ...,   31.977114,
#           43.970238,   46.955032],
#        ...,
#        [  37.141068,   36.11883 ,   32.13192 , ..., -121.73331 ,
#         -122.64945 , -122.62636 ],
#        [  37.14847 ,   35.126953,   31.116467, ..., -123.5131  ,
#         -124.37552 , -124.372   ],
#        [  39.19095 ,   37.12652 ,   33.143585, ..., -124.36978 ,
#         -124.339325, -124.26341 ]], dtype=float32)

# %%
x
# Out:
# array([[[[[0.03061405, 0.01316502, 0.00921854, ..., 0.03590868,
#            0.05010181, 0.08302307],
#           [0.00710112, 0.00407218, 0.0035686 , ..., 0.02975165,
#            0.02567778, 0.05343765],
#           [0.00507585, 0.00336274, 0.00398866, ..., 0.02288574,
#            0.02976398, 0.04496647],
#           ...,
#           [0.85893244, 0.88116956, 0.86807895, ..., 0.73330307,
#            0.6494486 , 0.6263546 ],
#           [0.85152745, 0.8730477 , 0.8835336 , ..., 0.5130962 ,
#            0.37551543, 0.37200096],
#           [0.8090525 , 0.8734819 , 0.85641605, ..., 0.36978343,
#            0.33932614, 0.2634099 ]]]],
#
#
#
#        [[[[0.17065126, 0.12064036, 0.10164824, ..., 0.9080296 ,
#            0.87771434, 0.79299784],
#           [0.09858356, 0.07908144, 0.07166645, ..., 0.9668455 ,
#            0.9369168 , 0.89584965],
#           [0.13728924, 0.12608546, 0.1047186 , ..., 0.97174186,
#            0.96687585, 0.9421861 ],
#           ...,
# ...
